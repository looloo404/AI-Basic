# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/DS_Sample_3.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       188 non-null    object
#  1   AirDate     188 non-null    object
#  2   Rating      188 non-null    float64
#  3   Num_Votes   188 non-null    int64
#  4   DirectedBy  188 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 7.5+ KB

# %%
df['success'] = df['Rating']*df['Num_Votes']

# %%
df.groupby('DirectedBy')['success'].mean().astype(int).max()
# Out:
# 32720

# %%
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols
import datetime

# %%
datetime?

# %%
df['AirDate'] = df['AirDate'].apply(lambda x : x[:4])

# %%
df['AirDate'] = df['AirDate'].astype(int)

# %%
df
# Out:
#                 Title  AirDate  Rating  Num_Votes       DirectedBy  success
# 0               Pilot     2005     7.5       4349       Ken Kwapis  32617.5
# 1       Diversity Day     2005     8.3       4213       Ken Kwapis  34967.9
# 2         Health Care     2005     7.8       3536  Ken Whittingham  27580.8
# 3        The Alliance     2005     8.1       3428     Bryan Gordon  27766.8
# 4          Basketball     2005     8.4       3745     Greg Daniels  31458.0
# ..                ...      ...     ...        ...              ...      ...
# 183     Stairmageddon     2013     8.0       1743        Matt Sohn  13944.0
# 184    Paper Airplane     2013     8.0       1748     Jesse Peretz  13984.0
# 185  Livin' the Dream     2013     9.0       2439    Jeffrey Blitz  21951.0
# 186          A.A.R.M.     2013     9.5       3401     David Rogers  32309.5
# 187            Finale     2013     9.8       9269       Ken Kwapis  90836.2
#
# [188 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       188 non-null    object
#  1   AirDate     188 non-null    int32
#  2   Rating      188 non-null    float64
#  3   Num_Votes   188 non-null    int64
#  4   DirectedBy  188 non-null    object
#  5   success     188 non-null    float64
# dtypes: float64(2), int32(1), int64(1), object(2)
# memory usage: 8.2+ KB

# %%
def test(x):
    if x>=2005 and x<=2007: return 'A'
    elif x>=2008 and x<=2010: return 'B'
    elif x>=2011 and x<=2013: return 'C'

# %%
df['AirDate'] = df['AirDate'].apply()

# %%
df['AirDate'] = df['AirDate'].apply(lambda x : 'B' if x>=2005 and x<=2007 else 'B')
# Out:
#                 Title AirDate  Rating  Num_Votes       DirectedBy  success
# 0               Pilot       A     7.5       4349       Ken Kwapis  32617.5
# 1       Diversity Day       A     8.3       4213       Ken Kwapis  34967.9
# 2         Health Care       A     7.8       3536  Ken Whittingham  27580.8
# 3        The Alliance       A     8.1       3428     Bryan Gordon  27766.8
# 4          Basketball       A     8.4       3745     Greg Daniels  31458.0
# ..                ...     ...     ...        ...              ...      ...
# 183     Stairmageddon       B     8.0       1743        Matt Sohn  13944.0
# 184    Paper Airplane       B     8.0       1748     Jesse Peretz  13984.0
# 185  Livin' the Dream       B     9.0       2439    Jeffrey Blitz  21951.0
# 186          A.A.R.M.       B     9.5       3401     David Rogers  32309.5
# 187            Finale       B     9.8       9269       Ken Kwapis  90836.2
#
# [188 rows x 6 columns]

# %%
# Out:
#                     Title AirDate  Rating  Num_Votes         DirectedBy  \
# 104            The Banker       B     6.8       2665      Jeffrey Blitz
# 105                 Sabre       B     7.7       1963     John Krasinski
# 106  Manager and Salesman       B     8.1       1942          Marc Webb
# 107  The Delivery: Part 1       B     8.4       2048        Seth Gordon
# 108  The Delivery: Part 2       B     8.5       2065        Seth Gordon
# 109     St. Patrick's Day       B     7.7       1922    Randall Einhorn
# 110             New Leads       B     7.8       1885    Brent Forrester
# 111            Happy Hour       B     8.6       2199          Matt Sohn
# 112       Secretary's Day       B     7.9       1892       Steve Carell
# 113         Body Language       B     8.0       1922       Mindy Kaling
# 114          The Cover-Up       B     8.2       1920       Rainn Wilson
# 115             The Chump       B     7.8       1850    Randall Einhorn
# ...

# %%
df['AirDate'].value_counts()
# Out:
# A       59
# 2009    29
# B       24
# 2011    23
# 2012    23
# 2008    16
# 2013    14
# Name: AirDate, dtype: int64
