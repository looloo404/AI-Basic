# %% [markdown]
# # [KDT] ch5 Linear Regression

# %% [markdown]
# ### 단일회귀 / 다중회귀 / 특성공학
#  - 데이터셋: 직장인 연봉 정보 / 보스톤집값 / 공유자전거 플랫폼 / 다이아몬드
#  - 주요 라이브러리: statsmodels ols / sklearn linear_model / sklearn train_test_split /
#  - 알파 퀴즈(1개) / 파이 퀴즈(1개) / 시그마 퀴즈(2개) / 오메가 퀴즈(과제 1개)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\강지윤\\Desktop\\인공지능기초'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 파일 로딩 
df_hk = pd.read_csv('.\\data\\hk_221206.csv')

# %%
df_hk
# Out:
#        name    jumin7 gender  height  age blood_type company grades  salary  \
# 0      hkd1  990623-2      F   161.9   22          A       A      A    4100
# 1     hkd10  900303-2      F   169.4   31          A       A      B    4720
# 2    hkd100  681205-2      F   168.3   55          A       A      B    7280
# 3    hkd101  931226-2      F   155.3   28         AB       B      B    4060
# 4    hkd102  920123-1      M   188.6   29          O       B      F    4390
# ..      ...       ...    ...     ...  ...        ...     ...    ...     ...
# 245   hkd95  730710-2      F   157.8   50          A       A      A    6990
# 246   hkd96  720805-2      F   150.4   51          O       A      A    7110
# 247   hkd97  710929-1      M   172.4   52          A       A      B    8000
# 248   hkd98  701024-1      M   166.7   53          O       A      B    8760
# 249   hkd99  691115-2      F   152.6   54          B       A      B    7470
#
#      expenditure
# 0           1975
# 1           2970
# 2           5905
# 3           2935
# 4           4015
# ..           ...
# 245         4865
# 246         4985
# 247         6625
# 248         7385
# 249         6095
#
# [250 rows x 10 columns]

# %% [markdown]
# ## $\alpha$(알파) 퀴즈:
# 전체 소득 대비 소비액 비율을 나타내는 합성 변수('expenditure_per_salary')를 만들고자 한다.
# <br> 수식 : expenditure_per_salary = expenditure / salary
# <br> expenditure_per_salary 합성변수를 만들고 해당 변수의 Company 그룹별 평균을 구하시오

# %%
df = df_hk.copy()

# %%
df['expenditure_per_salary'] = df['expenditure']/df['salary']

# %%
df.groupby('company')['expenditure_per_salary'].mean()
# Out:
# company
# A    0.765371
# B    0.751797
# C    0.790910
# Name: expenditure_per_salary, dtype: float64

# %% [markdown]
# ## 1-1. 단일 회귀 statemodels - ols()
#
# 연봉으로 지출액을 예측할 수 있을까 ?

# %%
# statemodels - ols() 클래스 호출
from statsmodels.formula.api import ols
  # formula 형식

# %%
# 시각화 (x="salary", y="expenditure")
sns.scatterplot( x="salary", y="expenditure", data = df, hue= 'company')
plt.show()

# %%
# 독립변수, 종속변수 상관계수 확인
df_hk[['expenditure','salary']].corr() #상관계쑤가 5보다 크면 강한 상관 관계
# Out:
#              expenditure    salary
# expenditure     1.000000  0.972185
# salary          0.972185  1.000000

# %%
# 모델선택, 독립변수(salary), 종속변수(expenditure) 입력, fit
from statsmodels.formula.api import ols
model1_1 = ols(formula='expenditure~salary', data = df_hk).fit()
model1_1

# %%
# Attribute 확인
model1_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            expenditure   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     4273.
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):          2.40e-158
# Time:                        09:56:29   Log-Likelihood:                -1873.6
# No. Observations:                 250   AIC:                             3751.
# Df Residuals:                     248   BIC:                             3758.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1246.9920     99.061    -12.588      0.000   -1442.100   -1051.884
# salary         0.9781      0.015     65.367      0.000       0.949       1.008
# ==============================================================================
# Omnibus:                        9.379   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                5.059
# Skew:                          -0.130   Prob(JB):                       0.0797
# Kurtosis:                       2.354   Cond. No.                     2.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# 모델 summary 결정계수 / 회귀 계수(coef) 등 확인 
model1_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            expenditure   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     4273.
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):          2.40e-158
# Time:                        09:56:29   Log-Likelihood:                -1873.6
# No. Observations:                 250   AIC:                             3751.
# Df Residuals:                     248   BIC:                             3758.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1246.9920     99.061    -12.588      0.000   -1442.100   -1051.884
# salary         0.9781      0.015     65.367      0.000       0.949       1.008
# ==============================================================================
# Omnibus:                        9.379   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                5.059
# Skew:                          -0.130   Prob(JB):                       0.0797
# Kurtosis:                       2.354   Cond. No.                     2.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## $$y= 0.9781 \times x - 1246.9920$$

# %%
# model1_1 attributes (params, predict, resid 잔차)
model1_1.params, model1_1.params[0], model1_1.params[1], model1_1.resid[1]
# Out:
# (Intercept   -1246.992024
#  salary          0.978135
#  dtype: float64,
#  -1246.992024494655,
#  0.9781347364827975,
#  -399.80393170414845)

# %%
# 회귀식
def liner1_1(salary):
    return (model1_1.params[1]*salary + model1_1.params[0])

# %%
# sample data
df[:2]
# Out:
#     name    jumin7 gender  height  age blood_type company grades  salary  \
# 0   hkd1  990623-2      F   161.9   22          A       A      A    4100
# 1  hkd10  900303-2      F   169.4   31          A       A      B    4720
#
#    expenditure  expenditure_per_salary
# 0         1975                0.481707
# 1         2970                0.629237

# %%
# 회귀식으로 예측값 확인
liner1_1(4390)
# Out:
# 3047.0194686648256

# %%
# sample data
df[:5]
# Out:
#      name    jumin7 gender  height  age blood_type company grades  salary  \
# 0    hkd1  990623-2      F   161.9   22          A       A      A    4100
# 1   hkd10  900303-2      F   169.4   31          A       A      B    4720
# 2  hkd100  681205-2      F   168.3   55          A       A      B    7280
# 3  hkd101  931226-2      F   155.3   28         AB       B      B    4060
# 4  hkd102  920123-1      M   188.6   29          O       B      F    4390
#
#    expenditure  expenditure_per_salary
# 0         1975                0.481707
# 1         2970                0.629237
# 2         5905                0.811126
# 3         2935                0.722906
# 4         4015                0.914579

# %%
# predict로 예측값 확인
pred = model1_1.predict(exog = df['salary'])
pred
df['predict'] = pred

# %%
df
# Out:
#        name    jumin7 gender  height  age blood_type company grades  salary  \
# 0      hkd1  990623-2      F   161.9   22          A       A      A    4100
# 1     hkd10  900303-2      F   169.4   31          A       A      B    4720
# 2    hkd100  681205-2      F   168.3   55          A       A      B    7280
# 3    hkd101  931226-2      F   155.3   28         AB       B      B    4060
# 4    hkd102  920123-1      M   188.6   29          O       B      F    4390
# ..      ...       ...    ...     ...  ...        ...     ...    ...     ...
# 245   hkd95  730710-2      F   157.8   50          A       A      A    6990
# 246   hkd96  720805-2      F   150.4   51          O       A      A    7110
# 247   hkd97  710929-1      M   172.4   52          A       A      B    8000
# 248   hkd98  701024-1      M   166.7   53          O       A      B    8760
# 249   hkd99  691115-2      F   152.6   54          B       A      B    7470
#
#      expenditure  expenditure_per_salary      predict
# 0           1975                0.481707  2763.360395
# 1           2970                0.629237  3369.803932
# 2           5905                0.811126  5873.828857
# 3           2935                0.722906  2724.235006
# 4           4015                0.914579  3047.019469
# ..           ...                     ...          ...
# 245         4865                0.695994  5590.169784
# 246         4985                0.701125  5707.545952
# 247         6625                0.828125  6578.085867
# 248         7385                0.843037  7321.468267
# 249         6095                0.815930  6059.674457
#
# [250 rows x 12 columns]

# %%
# 시각화 

fig, ax = plt.subplots( nrows= 1 , ncols=2, figsize=(14, 5))
sns.scatterplot(x=df['salary'], y=df['expenditure'], palette='Set1', ax= ax[0] )
sns.scatterplot(x=df['salary'], y=pred, palette='Set2', ax=ax[1] )

ax[0].set_title('expenditure ')
ax[1].set_title('predict1_1')
plt.show()

# %% [markdown]
# ## 다중 회귀 가정 4가지 선형성, 정규성, 등분산, 독립성

# %% [markdown]
# ### 선형 회귀 가정 1: 선형성
#
# F 검정의 pvalue로 확인

# %%
# 선형회귀 그래프, regplot: scatter plot, regression line, confidence band를 한 번에 그리는 기능
sns.regplot(x='salary', y='expenditure', data=df)
sns.regplot(x=df['salary'], y=pred)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
# F 검정의 pvalue로 확인
model1_1.f_pvalue<0.05 #선형성이 있다고 판단
# Out:
# True

# %% [markdown]
# ### 선형 회귀 가정 2: 잔차의 정규성
#
# <br>잔차 그래프로 확인
# <br>shapiro 의 경우 p값이 0.05 이상이면 정규성 만족한다

# %%
# 잔차 계산
model1_1.resid
residual = df['expenditure'] - pred
print(residual)
# Out:
# 0     -788.360395
# 1     -399.803932
# 2       31.171143
# 3      210.764994
# 4      967.980531
#           ...
# 245   -725.169784
# 246   -722.545952
# 247     46.914133
# 248     63.531733
# 249     35.325543
# Length: 250, dtype: float64

# %%
# 잔차 그래프 1
plt.scatter(df['salary'], residual)
plt.show()

# %%
# 잔차 그래프 2
sns.distplot(residual)
plt.show()

# %%
# shapiro 정규성 검정, Ho: 정규성을 가진다 (p-value > 0.05)
from scipy.stats import shapiro

# %%
# pvalue가 0.05보다 작으면 정규성 만족 못함
shapiro(residual)[1] < 0.05 #정규성을 만족하지 못함
# Out:
# True

# %%
# residual이 그룹화 되어 있어 shapiro test에서 정규성이 안 나옴

import scipy.stats as stats

stats.probplot(residual, plot=plt)
plt.show()

# %% [markdown]
# ## 선형 회귀 가정 3: 잔차의 등분산
#
# 예측값과 잔차의 산점도로 파악

# %%
# 잔차그래프로 확인, X가 커질때 잔차의 간격이 변하면 안됨, 간격아 일정하면 등분산성 만족
sns.regplot(x=pred, y=residual)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 선형 회귀 가정 4: 잔차의 독립성
# 잔차가 독립인지(자기상관성이 있는지) 검정

# %%
#perform Durbin-Watson test

from statsmodels.stats.stattools import durbin_watson
durbin_watson(model1_1.resid)

# 더빈 왓슨 통계량은 0 ~ 4사이의 값을 갖을 수 있음
# 0에 가까울수록 → 양의 상관관계
# 4에 가까울수록 → 음의 상관관계
# 2에 가까울수록 → 오차항의 자기상관이 없음
# Out:
# 1.8401707978491966

# %% [markdown]
# ## 1-2. 단일 회귀 sklearn.linear_model
#
# 연봉으로 지출액을 예측할 수 있을까 ?

# %%
# LinearRegression 호출
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression

# %%
df[['salary']].values
# Out:
# array([[ 4100],
#        [ 4720],
#        [ 7280],
#        [ 4060],
#        [ 4390],
#        [ 3290],
#        [ 3750],
#        [ 3080],
#        [ 3110],
#        [ 3230],
#        [ 3410],
#        [ 3420],
#        [ 4820],
#        [ 3460],
#        [ 4370],
#        [ 3260],
#        [ 3540],
#        [ 4040],
#        [ 5230],
#        [ 4590],
#        [ 4730],
#        [ 4950],
#        [ 4450],
#        [ 5080],
#        [ 5660],
#        [ 6060],
#        [ 6130],
#        [ 6050],
#        [ 6250],
#        [ 5710],
#        [ 6210],
#        [ 6920],
#        [ 7000],
#        [ 7420],
#        [ 4990],
#        [ 7000],
#        [ 7250],
#        [ 7420],
#        [ 7460],
#        [ 7250],
#        [ 7430],
#        [ 6440],
#        [ 8460],
#        [ 4060],
#        [ 3530],
#        [ 5070],
#        [ 3680],
#        [ 3860],
#        [ 4580],
#        [ 4000],
#        [ 4920],
#        [ 4450],
#        [ 5110],
#        [ 5390],
#        [ 5440],
#        [ 5920],
#        [ 5550],
#        [ 6420],
#        [ 6130],
#        [ 6320],
#        [ 5840],
#        [ 6310],
#        [ 7330],
#        [ 6440],
#        [ 6200],
#        [ 3980],
#        [ 3330],
#        [ 5440],
#        [ 3600],
#        [ 3820],
#        [ 4770],
#        [ 4960],
#        [ 4850],
#        [ 4390],
#        [ 5010],
#        [ 5480],
#        [ 6010],
#        [ 5830],
#        [ 4720],
#        [ 6300],
#        [ 6110],
#        [ 6730],
#        [ 6660],
#        [ 7250],
#        [ 6750],
#        [ 5420],
#        [ 6170],
#        [ 4800],
#        [ 5160],
#        [ 5770],
#        [ 6130],
#        [ 5010],
#        [ 5380],
#        [ 5410],
#        [ 5790],
#        [ 6300],
#        [ 6620],
#        [ 5510],
#        [ 4710],
#        [ 4770],
#        [ 6090],
#        [ 4800],
#        [ 5260],
#        [ 5300],
#        [ 5730],
#        [ 5760],
#        [ 6280],
#        [ 6420],
#        [ 6060],
#        [ 4500],
#        [ 5160],
#        [ 4120],
#        [ 6210],
#        [ 5750],
#        [10390],
#        [ 7680],
#        [ 8750],
#        [ 9170],
#        [ 5040],
#        [ 5710],
#        [ 5280],
#        [ 5710],
#        [ 5740],
#        [ 6610],
#        [ 5950],
#        [ 6380],
#        [ 6520],
#        [ 7520],
#        [ 6930],
#        [ 8360],
#        [ 8530],
#        [ 7670],
#        [ 8570],
#        [ 9030],
#        [ 6610],
#        [11180],
#        [ 9800],
#        [ 9830],
#        [ 4970],
#        [ 5190],
#        [ 5210],
#        [ 5550],
#        [ 5710],
#        [ 5810],
#        [ 6070],
#        [ 7120],
#        [ 6430],
#        [ 7430],
#        [ 6900],
#        [ 7320],
#        [ 8450],
#        [10800],
#        [10410],
#        [10480],
#        [ 9380],
#        [ 9430],
#        [ 7300],
#        [11440],
#        [11120],
#        [11720],
#        [11080],
#        [11810],
#        [11990],
#        [10530],
#        [ 5540],
#        [ 6580],
#        [ 5540],
#        [ 6770],
#        [ 8050],
#        [ 6480],
#        [ 8520],
#        [ 6680],
#        [ 5800],
#        [ 4420],
#        [ 7950],
#        [ 8720],
#        [ 8220],
#        [ 7520],
#        [ 9430],
#        [ 4580],
#        [ 4670],
#        [ 4760],
#        [ 4610],
#        [ 5100],
#        [ 4450],
#        [ 5000],
#        [ 4970],
#        [ 5620],
#        [ 5460],
#        [ 5650],
#        [ 5800],
#        [ 6200],
#        [ 6190],
#        [ 6530],
#        [ 5120],
#        [ 4550],
#        [ 6020],
#        [ 7530],
#        [ 7540],
#        [ 7630],
#        [ 7200],
#        [ 6860],
#        [ 8040],
#        [ 7230],
#        [ 8000],
#        [ 8100],
#        [ 4160],
#        [ 9440],
#        [ 4750],
#        [ 6190],
#        [ 4620],
#        [ 6370],
#        [ 5590],
#        [ 5640],
#        [ 7150],
#        [ 8850],
#        [ 7590],
#        [ 4630],
#        [ 6830],
#        [ 7800],
#        [ 8860],
#        [ 9300],
#        [ 8260],
#        [ 8730],
#        [ 9120],
#        [ 8870],
#        [ 7830],
#        [ 8110],
#        [ 4570],
#        [ 8800],
#        [ 7650],
#        [ 9310],
#        [ 5450],
#        [ 5270],
#        [ 4740],
#        [ 5650],
#        [ 4600],
#        [ 5640],
#        [ 6240],
#        [ 4950],
#        [ 7210],
#        [ 6920],
#        [ 6610],
#        [ 7560],
#        [ 8540],
#        [ 6990],
#        [ 7110],
#        [ 8000],
#        [ 8760],
#        [ 7470]], dtype=int64)

# %%
# 모델선택, 독립변수(salary), 종속변수(expenditure) 입력, fit 
model1_2 = LinearRegression(fit_intercept=True).fit(X = df[['salary']].values,
                                                 y = df['expenditure']                                              )

# %%
# 회귀계수 확인
model1_2.coef_, model1_2.intercept_
# Out:
# (array([0.97813474]), -1246.9920244946543)

# %%
# intercept_ 확인
df[:5]
# Out:
#      name    jumin7 gender  height  age blood_type company grades  salary  \
# 0    hkd1  990623-2      F   161.9   22          A       A      A    4100
# 1   hkd10  900303-2      F   169.4   31          A       A      B    4720
# 2  hkd100  681205-2      F   168.3   55          A       A      B    7280
# 3  hkd101  931226-2      F   155.3   28         AB       B      B    4060
# 4  hkd102  920123-1      M   188.6   29          O       B      F    4390
#
#    expenditure  expenditure_per_salary      predict
# 0         1975                0.481707  2763.360395
# 1         2970                0.629237  3369.803932
# 2         5905                0.811126  5873.828857
# 3         2935                0.722906  2724.235006
# 4         4015                0.914579  3047.019469

# %% [markdown]
# ## $$y= 0.97813 \times x - 1246.9920$$

# %%
# 회귀식
def liner1_2(salary):
    return (model1_2.coef_[0] * salary) + model1_2.intercept_

# %%
# 회귀식으로 예측
liner1_2(4100),liner1_1(4100
# Out:
#   File "C:\Users\강지윤\AppData\Local\Temp\ipykernel_7756\1901085134.py", line 2
#     liner1_2(4100),liner1_1(4100
#                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
# predict로 예측
pred1_2 = model1_2.predict(df[['salary']])
pred1_2[:5]
# Out:
# array([2763.36039508, 3369.8039317 , 5873.8288571 , 2724.23500563,
#        3047.01946866])

# %%
# 선형회귀 그래프
sns.regplot(x=df['salary'], y=pred1_2)
# Out:
# <AxesSubplot:xlabel='salary'>

# %% [markdown]
# ## statemodels vs. sklearn 비교
#  - statemodels는 통계기반 강점, summary 표등 통계자료 보기 편함
#  - sklearn는 머신러닝 관점
#  - 입력값의 차이( statemodels ols의 경우 formula 문법이 있음 / sklearn는 fit() 활용)

# %%
# statemodels vs. sklearn 제공 기능 비교

# model1_1.   # 통계 중심
# model1_2.   # 머신러닝 중심

# %%
# train_test_split (train_size= 0.7, random_state=123)
from sklearn.model_selection import train_test_split

df_train1, df_test1 = train_test_split(df_hk,train_size=0.7,random_state = 128,shuffle=True)

print('데이터셋 총합 :', len(df), ', df_train :', len(df_train1), ', df_test :', len(df_test1))
print(type(df_train1))
# Out:
# 데이터셋 총합 : 250 , df_train : 175 , df_test : 75
# <class 'pandas.core.frame.DataFrame'>

# %%
# ols 모델링, fit
from statsmodels.formula.api import ols
model1_3 = ols(formula='expenditure ~ salary',data=df_train1).fit()
#feature 여러개면 'expenditure~salary+age + ...'

# %%
# summary, 회귀계수 확인
model1_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            expenditure   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     3156.
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):          5.04e-113
# Time:                        09:56:53   Log-Likelihood:                -1305.3
# No. Observations:                 175   AIC:                             2615.
# Df Residuals:                     173   BIC:                             2621.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1219.0989    114.162    -10.679      0.000   -1444.429    -993.769
# salary         0.9742      0.017     56.180      0.000       0.940       1.008
# ==============================================================================
# Omnibus:                        3.845   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.146   Jarque-Bera (JB):                2.610
# Skew:                          -0.116   Prob(JB):                        0.271
# Kurtosis:                       2.448   Cond. No.                     2.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## $$y= 0.9799 \times x - 1278.0961$$

# %%
# model1_3 과 model1_1.summary()와 비교, coef_, R-squared, train data set이 바뀌었음
df_test1
# Out:
#        name    jumin7 gender  height  age blood_type company grades  salary  \
# 37   hkd132  730706-1      M   181.5   50          B       B      B    7420
# 118  hkd205  990624-2      F   160.3   22          A       C      A    5040
# 122  hkd209  951016-2      F   167.8   26          A       C      B    5740
# 136  hkd221  830811-1      M   191.0   38          O       C      A    9800
# 93   hkd183  811011-2      F   152.0   40          O       B      A    5410
# ..      ...       ...    ...     ...  ...        ...     ...    ...     ...
# 134   hkd22  780912-1      M   183.4   43          O       A      A    6610
# 137  hkd222  820907-2      F   154.4   39          B       C      D    9830
# 41   hkd136  690111-2      F   164.7   54          O       B      C    6440
# 92   hkd182  820404-1      M   178.5   39          A       B      B    5380
# 165  hkd248  910218-2      F   168.2   30          O       C      C    6580
#
#      expenditure
# 37          6295
# 118         2915
# 122         3990
# 136         7675
# 93          4035
# ..           ...
# 134         4485
# 137         9080
# 41          5315
# 92          4005
# 165         5455
#
# [75 rows x 10 columns]

# %%
# 회귀식 y = 0.9799 * salary - 1278.0961

0.9742 * 5040- 1219.0989
# 0.9799 * ? - 1278.0961
# Out:
# 3690.8691

# %%
# predict로 예측
model1_3.predict(df_test1['salary'])
# Out:
# 37     6009.506922
# 118    3690.897517
# 122    4372.841460
# 136    8328.116326
# 93     4051.353601
#           ...
# 134    5220.400360
# 137    8357.342495
# 41     5054.785402
# 92     4022.127432
# 165    5191.174191
# Length: 75, dtype: float64

# %% [markdown]
# ## 1-4. $\pi$(파이) Quiz 단일회귀 train_test_split / statemodels - ols()
#
#
# <br>나이로 연봉을 예측할 수 있을까 ?
# <br>독립변수: 나이(age)
# <br>종속변수: 연봉(salary)
#
# <br>1. train, test data 분할하시오(train_size= 0.7, random_state=123)
# <br>2. 회귀식을 수립하시오
# <br>3. 37세의 연봉을 예측하시오

# %%
# train_test_split (train_size= 0.7, random_state=123)
df_train1, df_test1 = train_test_split(df, train_size= 0.7, random_state=123)

# %%
# ols모델링, fit
from statsmodels.formula.api import ols
model_myself = ols(formula='salary~age',data=df_train1).fit()
model_myself.summary()

# %%
# summary, 회귀계수 확인
115.2576*37+1821.4088

# %%
model_myself.predict(pd.DataFrame({'age':[37]}))

# %% [markdown]
# ## $$y= 115.2576 \times x + 1821.4088$$

# %%
# 회귀식으로 예측 y = 115.2576 * age + 1821.4088
115.2576 * ? + 1821.4088
115.2576 * ? + 1821.4088

# %%
# predict 개별값 입력으로 예측
model_myself.predict(pd.DataFrame({'age':[37]}))

# %%
model_myself.predict(exog=pd.DataFrame(data=[37],columns=['age']))

# %%
# predict 전체값 예측
model_myself.predict(df['age'])

# %%
# 선형회귀 그래프
sns.regplot(x='age', y='salary', data=df_test1)

# %% [markdown]
# ## 1-5.  $\pi$(파이) Quiz 단일회귀 train_test_split /  sklearn.linear_model
#
#
# <br>나이로 연봉을 예측할 수 있을까 ?
# <br>독립변수: 나이(age)
# <br>종속변수: 연봉(salary)
#
# train, test data 분할하고 37세의 연봉을 예측하시오

# %%
# train_test_split (train_size= 0.7, random_state=123)
df_train1, df_test1 = train_test_split(df, train_size= 0.7, random_state=123)

# %%
# LinearRegression, fit, predict
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

model_myself2 = LinearRegression(fit_intercept=True).fit(X =df_train1[['age']],
                                                         y= df_train1[['salary']])

# %%
print(model_myself2.predict(pd.DataFrame(data=[37],columns=['age'])))
model_myself2.predict(X = df_test1[:5][['age']])

# %% [markdown]
# ## 1-6. 단일회귀 train_test_split /  statsmodels.api ,

# %%
# statsmodels.api
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split


model1_4 = sm.OLS(endog=df_train1['salary'], exog = sm.add_constant(df_train1[['age']])).fit()# intercept 포함하려면 sm.add_constatant

# train, fit

# %%
# predict
model1_4.predict(sm.add_constant(df_train1['age']))

# %%
# summary()
model_myself2.predict(df_train1[['age']])

# %% [markdown]
# ## 2-1. 다중회귀 statemodels -ols()
#
# 연봉과 나이로 지출액을 예측할 수 있을까
# <br> train, test data 분할
# <br> 종속변수 : 지출액 (expenditure)
# <br> 독립변수 : 연봉과 나이 (age , salary)

# %%
# ols 다중회귀 모델링, fit
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# summary
model1_5 = LinearRegression(fit_intercept=True).fit(X=df_train1[['age','salary']],y = df_train1[['expenditure']])
model1_5.coef_, model1_5.intercept_

# %%
# attribute 확인
model1_6 = sm.OLS(endog = df_train1['expenditure'],exog=sm.add_constant(df_train1[['age','salary']])).fit()

# %%
df_test1

# %%
model1_6.predict(sm.add_constant(df_test1[['age','salary']]))

# %%
model1_6.summary()

# %% [markdown]
# ## $$y= 14.9256 \times x_1  + 0.9436 \times x_2 - 1633.1811$$

# %%
df_test1.head(1)

# %%
# 회귀식, hkd213에 대입 나이 30 / 연봉 7520
14.9256 * ? + 0.9436 * ? - 1633.1811

# %%
# predict 예측

# %%
# attribute로 확인

# %%
# 회귀식에 attribute값 대입, (나이 30 / 연봉 7520)

# %% [markdown]
# ## 다중회귀 2-2 sklearn.linear_model
#
# <br> 연봉과 지출액으로 나이를 예측할 수 있을까
# <br> train, test data 분할
# <br> 독립변수: salary, expenditure
# <br> 종속변수: age

# %%
# LinearRegression, fit, predict
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

model2_2 = LinearRegression(fit_intercept=True).fit(y=df_train1['age'], X= df_train[['salary','expenditure']])
model2_2.predict(df_test1[:5][['salary','expenditure']]), df_test1[:5]['age']

# %%
# intercept_, coef_확인
model2_2.coef_, model2_2.intercept_,model2_2.feature_names_in_

# %%
# 변수별 회귀계수 확인하는 데이터프레임
pd.DataFrame(({'feature':model2_2.feature_names_in_,'coef':model2_2.coef_}))

# %% [markdown]
# ## 2-3 선형회귀 모형 명목형 변수의 처리
# get_dummy ('gender', 'blood_type', 'company', 'grades')

# %%
# 해당 column만 get_dummies
df_dum

# %%
# 전체 column + 해당 column, 원본 column은 삭제됨
df_dum = pd.get_dummies(data = df, columns=['gender','company'],drop_first=True)

# %%
(df_dum['company_B'] ==0)  & (df_dum['company_C'] == 0)

# %% [markdown]
# ## 2-4 다중회귀 sklearn.linear_model
#
# 회사와(company, 범주형) 연봉(salary, 연속형)으로 지출액(expenditure)을 예측할 수 있을까 ?

# %%
# LinearRegression, fit, predict
from sklearn.linear_model import LinearRegression

model2_4 = LinearRegression().fit(X = df_dum[['company_B','company_C','salary']],
                       y = df_dum['expenditure'])

# %%
model2_4
predict2_4 = model2_4.predict(X=df_dum[['company_B','company_C','salary']])
predict2_4[:5],df_dum['expenditure'][:5]

# %%
# attribute 확인(coef, intercept)
model2_4.coef_, model2_4.intercept_, model2_4.feature_names_in_

# %%
# feature, coef DataFrame화
pd.DataFrame({'feature':model2_4.feature_names_in_, 'coef':model2_4.coef_})

# %%
model2_4.intercept_

# %% [markdown]
# ## $$y= -30.55 \times x_1  + 177.91 \times x_2 -147.36 \times x_3 + 1.01 \times x_4 - 1503.1087$$

# %% [markdown]
# ## 3-1 선형회귀 모델의 평가
#
# MSE, RMSE, MAE, RMAE

# %%
#df_train1, df_test1
df_train1, df_test1
# Out:
# (       name    jumin7 gender  height  age blood_type company grades  salary  \
#  193   hkd48  780113-1      M   184.0   43         AB       A      C    6530
#  243   hkd93  730719-1      M   180.4   48         AB       A      B    7560
#  152  hkd236  860621-1      M   166.2   35          A       C      B   10410
#  184    hkd4  960809-1      M   177.6   25          O       A      B    4450
#  190   hkd45  811022-1      M   182.1   40          B       A      C    5800
#  ..      ...       ...    ...     ...  ...        ...     ...    ...     ...
#  98   hkd188  860617-2      F   164.1   35          O       B      B    4710
#  220   hkd72  720803-1      M   183.2   51          B       A      A    8860
#  66   hkd159  900303-1      M   170.1   31          B       B      B    3330
#  126  hkd212  920124-2      F   158.3   29          O       C      C    6520
#  109  hkd198  830108-1      M   188.1   38          A       B      B    4500
#
#       expenditure  expenditure_per_salary      predict
#  193         5405                0.827718  5140.227805
#  243         6185                0.818122  6147.706583
#  152         9285                0.891931  8935.390582
#  184         3075                0.691011  3105.707553
#  190         4675                0.806034  4426.189447
#  ..           ...                     ...          ...
#  98          3335                0.708068  3360.022584
#  220         6735                0.760158  7419.281741
#  66          2205                0.662162  2010.196648
#  126         5770                0.884969  5130.446457
#  109         3125                0.694444  3154.614290
#
#  [175 rows x 12 columns],
#         name    jumin7 gender  height  age blood_type company grades  salary  \
#  127  hkd213  910216-2      F   158.3   30          B       C      C    7520
#  187   hkd42  840718-1      M   191.5   37          O       A      B    5620
#  24   hkd120  830831-1      M   183.8   38          O       B      A    5660
#  206    hkd6  941105-2      F   156.3   27          O       A      F    4160
#  235   hkd86  801119-2      F   151.3   41          A       A      A    5650
#  ..      ...       ...    ...     ...  ...        ...     ...    ...     ...
#  128  hkd214  900305-1      M   179.0   31          A       C      A    6930
#  132  hkd218  860620-1      M   172.5   35          A       C      B    8570
#  167   hkd25  750420-2      F   149.5   46          A       A      B    6770
#  217    hkd7  931225-1      M   189.4   28          A       A      A    4630
#  50   hkd144  850914-2      F   163.5   36          A       B      A    4920
#
#       expenditure  expenditure_per_salary      predict
#  127         6770                0.900266  6108.581194
#  187         3870                0.688612  4250.125195
#  24          4285                0.757067  4289.250584
#  206         3785                0.909856  2822.048479
#  235         3525                0.623894  4279.469237
#  ..           ...                     ...          ...
#  128         4805                0.693362  5531.481699
#  132         6820                0.795799  7135.622667
#  167         5020                0.741507  5374.980141
#  217         2505                0.541037  3281.771805
#  50          3545                0.720528  3565.430879
#
#  [75 rows x 12 columns])

# %%
# 평가를 위한 시각화 (x='salary', y='expenditure')
sns.regplot(x='salary', y='expenditure', data=df_train1) # 평가는 회귀식과 실제값이 잘 맞는가
# Out:
# <AxesSubplot:xlabel='salary', ylabel='expenditure'>

# %%
# 평가를 위한 시각화 (x='age', y='expenditure')
sns.regplot(x='age', y='expenditure', data=df_train1)  # 그래프로 보면 age가 불리해 보임
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenditure'>

# %%
# LinearRegression (salary, expenditure)
from sklearn.linear_model import LinearRegression
model_salary = LinearRegression().fit(X = df_train1[['salary']],
                                     y=df_train1[['expenditure']])
predict_salary = model_salary.predict(X=df_test1[['salary']])

# %%
# LinearRegression (age, expenditure)
from sklearn.linear_model import LinearRegression
model_age = LinearRegression().fit(X = df_train1[['age']], 
                                   y = df_train1['expenditure'])
predict_age = model_age.predict(X = df_test1[['age']])

# %%
# predict_salary 시각화
sns.regplot(x=predict_salary, y=df_test1['expenditure'])
# Out:
# <AxesSubplot:ylabel='expenditure'>

# %%
# predict_age 시각화
sns.regplot(x=predict_age, y=df_test1['expenditure'])
# Out:
# <AxesSubplot:ylabel='expenditure'>

# %%
# LinearRegression 평가를 위한 class
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ### Mean Absolute Error(MAE) : $$\frac{1}{N}\sum_{i=1}^{n}|x_i-y_i|$$

# %%
# Mean Absolute Error(MAE) 계산식
from sklearn.metrics import mean_absolute_error

# %%
# mean_absolute_error class 활용 (predict_salary)
mean_absolute_error(y_true=df_test1[['expenditure']],y_pred=predict_salary)
# Out:
# 376.86984466963213

# %%
(df_test1[['expenditure']] - predict_salary).abs().sum()/df_test1.shape[0]
# Out:
# expenditure    376.869845
# dtype: float64

# %%
# mean_absolute_error class 활용 (predict_age)
mean_absolute_error(y_true=df_test1[['expenditure']],y_pred=predict_age)
# Out:
# 1037.0895563016563

# %% [markdown]
# ### Mean Squared Error(MSE): $$\frac{1}{N}\sum_{i=1}^{n}(x_i-y_i)^2$$

# %%
# Mean Squared Error(MSE) 계산식
((df_test1[['expenditure']]-predict_salary)**2).sum()/len(df_test1)
# Out:
# expenditure    216029.475908
# dtype: float64

# %%
# mean_squared_error  class 활용 (predict_salary)
mean_squared_error(y_true=df_test1['expenditure'],y_pred = predict_salary)
# Out:
# 216029.47590795337

# %%
# mean_squared_error  class 활용 (predict_age)
mean_squared_error(y_true=df_test1['expenditure'],y_pred = predict_age)
# Out:
# 2066567.1581136591

# %% [markdown]
# ### Root Mean Squared Error(RMSE):
# $$\sqrt{\frac{1}{N}\sum_{i=1}^{n}(x_i-y_i)^2 }$$

# %%
# Root Mean Squared Error(RMSE) 계산식
(((df_test1[['expenditure']]-predict_salary)**2).sum()/len(df_test1))**0.5
# Out:
# expenditure    464.789711
# dtype: float64

# %%
# RMSE (mean_squared_error 활용) (predict_salary)
mean_squared_error(y_true=df_test1['expenditure'],y_pred = predict_salary)**.5
# Out:
# 464.7897114910714

# %%
# RMSE (mean_squared_error 활용) (predict_age)
mean_squared_error(y_true=df_test1['expenditure'],y_pred = predict_age)**0.5
# Out:
# 1437.555966950038

# %% [markdown]
# ## 3-2 정규화, 표준화

# %% [markdown]
# 표준화 : min-max 단위를 고르게 하기 위하여 모든 값을 0~1사이로 바꾸는 것
# <br> sklearn.preprocessing / MinMaxScaler 활용

# %% [markdown]
# $$Y = \frac{( X - X_{min} )}{( X_{max} - X_{min} )} $$

# %%
# MinMaxScaler class
from sklearn.preprocessing import MinMaxScaler

# %%
# 대상변수 선택 (수치형) 'height', 'age', 'salary', 'expenditure'
df_n = df[['height','age','salary','expenditure']]
df_n[:2]
# Out:
#    height  age  salary  expenditure
# 0   161.9   22    4100         1975
# 1   169.4   31    4720         2970

# %%
# MinMaxScaler 모델링
minmaxscaler= MinMaxScaler()

# %%
# MinMaxScaler fit, transform
df_n_scaled = minmaxscaler.fit_transform(df_n)

# %%
#minmax dataFrame화
df_minmax = pd.DataFrame(df_n_scaled,columns= df_n.columns)

# %%
df_minmax[:5]
# Out:
#      height       age    salary  expenditure
# 0  0.315789  0.057143  0.114478     0.067646
# 1  0.487414  0.314286  0.184063     0.171998
# 2  0.462243  1.000000  0.471380     0.479811
# 3  0.164760  0.228571  0.109989     0.168327
# 4  0.926773  0.257143  0.147026     0.281594

# %%
# 시각화 

fig, ax = plt.subplots( nrows= 1 , ncols=2, figsize=(14, 5))

ax[0].set_title('original ')
ax[1].set_title('minmax')

df_n.plot.hist(ax= ax[0] )
df_minmax.plot.hist(ax= ax[1] )
plt.show()

# %% [markdown]
# ### 정규화

# %% [markdown]
# 정규화: StandardScaler 모든 변수의 값을 평균이 0이고 분산이 1인 정규 분포로 변환
# <br> sklearn.preprocessing / MinMaxScaler 활용

# %% [markdown]
# $$Z = \frac{ X - \mu }{\sigma} $$

# %%
# StandardScaler class
from sklearn.preprocessing import StandardScaler

# %%
# StandardScaler 모델링
sc_stan = StandardScaler()

# %%
# StandardScaler fit, transform
sc_stan.fit_transform(df_n)
# Out:
# array([[-0.62558401, -1.99616204, -1.22284522, -1.61327753],
#        [-0.01380181, -0.95408209, -0.88699992, -1.0775786 ],
#        [-0.10352986,  1.82479778,  0.49971613,  0.50259866],
#        [-1.16395235, -1.30144208, -1.24451266, -1.09642228],
#        [ 1.55236064, -1.18565541, -1.06575629, -0.51496012],
#        [-1.57996425, -1.06986875, -1.66161085, -1.64558099],
#        [ 0.52456653, -1.99616204, -1.41243531, -1.39792118],
#        [-0.50322757, -1.88037538, -1.7753649 , -1.96053966],
#        [ 1.36474743, -1.76458872, -1.75911432, -1.40599704],
#        [ 0.99767811, -1.64880206, -1.694112  , -1.87978103],
#        [ 0.04329787, -1.5330154 , -1.59660853, -1.78287066],
#        [ 0.67139426, -1.41722874, -1.59119167, -1.77748676],
#        [ 1.51973225, -0.83829543, -0.83283133, -1.02373951],
#        [-0.51954176, -1.30144208, -1.56952423, -1.75595112],
#        [-1.0660672 , -1.18565541, -1.07659001, -0.72762452],
#        [-0.27482888, -1.06986875, -1.67786143, -1.32523841],
#        [-0.62558401, -0.95408209, -1.52618936, -1.17448896],
#        [-0.98449624, -0.83829543, -1.25534638, -1.24178782],
#        [-0.89476818, -0.72250877, -0.61074009, -0.80299924],
#        [ 0.35326752, -0.60672211, -0.9574191 , -0.60917852],
#        [-0.53585595, -0.49093544, -0.88158307, -0.87029811],
#        [-0.38087113, -0.37514878, -0.76241215, -0.75185211],
#        [-1.29446589, -0.25936212, -1.03325513, -1.02104756],
#        [ 0.05145496, -0.72250877, -0.69199298, -1.08565446],
#        [ 1.16082003, -0.14357546, -0.37781512, -0.36959458],
#        [-1.32709427, -0.0277888 , -0.16114074, -0.35613481],
#        [ 0.1901256 ,  0.08799786, -0.12322272, -0.11655086],
#        [ 1.2260768 ,  0.20378452, -0.1665576 , -0.36151871],
#        [ 0.94057843,  0.31957119, -0.05822041, -0.05194395],
#        [-0.03827309,  0.43535785, -0.35073082, -0.34267503],
#        [ 1.69918837,  0.55114451, -0.07988785, -0.07347959],
#        [-0.52769886,  0.66693117,  0.30470919,  0.10688136],
#        [-1.75126327,  0.78271783,  0.34804406,  0.14995263],
#        [ 1.2097626 ,  0.89850449,  0.57555217,  0.71257111],
#        [ 0.89163586, -0.60672211, -0.74074472, -1.13410964],
#        [ 0.45930977,  1.01429115,  0.34804406,  0.48644694],
#        [-1.0579101 ,  1.13007782,  0.48346555,  0.48644694],
#        [ 0.97320682,  1.24586448,  0.57555217,  0.71257111],
#        [-1.63706392,  1.36165114,  0.5972196 ,  0.73410675],
#        [ 1.03030649,  1.4774378 ,  0.48346555,  0.82294124],
#        [ 1.71550256,  1.59322446,  0.58096903,  0.9198516 ],
#        [-0.39718532,  1.70901112,  0.04469993,  0.18494804],
#        [ 1.08740616,  1.82479778,  1.13890556,  1.27249764],
#        [-0.06274438, -1.06986875, -1.24451266, -1.23102   ],
#        [ 0.19828269, -0.95408209, -1.53160622, -1.38176945],
#        [ 0.5898233 , -0.49093544, -0.69740984, -1.09103837],
#        [ 1.37290452, -0.83829543, -1.45035332, -1.43560854],
#        [ 0.92426424, -0.72250877, -1.35284985, -1.20410046],
#        [ 0.95689263, -0.60672211, -0.96283596, -0.95105674],
#        [ 0.98136391, -0.49093544, -1.27701382, -1.26332346],
#        [-0.49507047, -0.37514878, -0.77866273, -0.76800384],
#        [-1.35972266, -0.25936212, -1.03325513, -0.88644983],
#        [-0.6500553 , -0.14357546, -0.6757424 , -0.53111185],
#        [-0.35639984, -0.0277888 , -0.52407033, -0.51496012],
#        [-0.78056884,  0.08799786, -0.49698603, -0.48804057],
#        [ 0.30432494,  0.20378452, -0.23697677, -0.09501522],
#        [-1.49839329, -0.37514878, -0.43740058, -0.63071416],
#        [ 1.07109197,  0.31957119,  0.03386621,  0.0395825 ],
#        [ 0.50825234,  0.43535785, -0.12322272, -0.11655086],
#        [ 0.5898233 ,  0.55114451, -0.02030239, -0.01425659],
#        [-1.66153521,  0.66693117, -0.28031165, -0.27268422],
#        [ 1.31580485,  0.78271783, -0.02571925,  0.45145153],
#        [ 0.11671173,  0.89850449,  0.52680043,  0.66411593],
#        [-1.33525137,  1.01429115,  0.04469993,  0.18494804],
#        [-0.59295563,  1.13007782, -0.0853047 ,  0.05573422],
#        [ 1.39737581, -1.06986875, -1.28784753, -1.13949355],
#        [ 0.04329787, -0.95408209, -1.63994341, -1.48944763],
#        [ 1.43816129, -0.25936212, -0.49698603, -0.68993716],
#        [-0.28298598, -0.83829543, -1.4936882 , -1.34408209],
#        [-1.52286458, -0.72250877, -1.37451729, -1.36023382],
#        [-0.42165661, -0.60672211, -0.85991563, -0.37767044],
#        [-0.27482888, -0.49093544, -0.75699529, -0.61187048],
#        [ 1.30764776, -0.37514878, -0.81658075, -0.67109348],
#        [ 0.85900747, -0.25936212, -1.06575629, -0.91875329],
#        [-0.56848434, -0.14357546, -0.729911  , -0.58495093],
#        [-0.2340434 , -0.0277888 , -0.4753186 , -0.33190722],
#        [ 1.4300042 ,  0.08799786, -0.18822504, -0.04656004],
#        [-1.15579526,  0.20378452, -0.28572851, -0.1434704 ],
#        [-1.2699946 , -0.14357546, -0.88699992, -0.53918771],
#        [ 0.96504972,  0.31957119, -0.03113611,  0.10957331],
#        [-0.07090148,  0.43535785, -0.13405644,  0.00727904],
#        [ 0.05961206,  0.55114451,  0.20178885,  0.20648367],
#        [ 0.60613749,  0.66693117,  0.16387084,  0.16879631],
#        [-0.25035759,  0.78271783,  0.48346555,  0.82294124],
#        [-1.49023619,  0.89850449,  0.21262257,  0.21725149],
#        [-0.49507047,  1.01429115, -0.50781975, -0.49880839],
#        [-1.66153521,  1.13007782, -0.10155528, -0.09501522],
#        [ 0.7937507 , -0.49093544, -0.84366505, -0.83261074],
#        [-0.2258863 , -0.37514878, -0.6486581 , -0.63879002],
#        [ 1.39737581, -0.0277888 , -0.31822967,  0.02612273],
#        [ 1.31580485, -0.25936212, -0.12322272, -0.11655086],
#        [-1.66153521, -0.14357546, -0.729911  , -0.71954866],
#        [ 0.72849394, -0.0277888 , -0.52948719, -0.52034403],
#        [-1.43313652,  0.08799786, -0.51323661, -0.5041923 ],
#        [-0.51954176,  0.20378452, -0.30739595, -0.16500604],
#        [-0.27482888,  0.31957119, -0.03113611,  0.10957331],
#        [-1.13132397,  0.43535785,  0.1422034 ,  0.14726068],
#        [-0.87845399,  0.55114451, -0.45906802, -0.45035321],
#        [-0.4461279 , -0.49093544, -0.89241678, -0.88106592],
#        [-1.04159591, -0.37514878, -0.85991563, -0.84876247],
#        [ 1.49526097,  0.08799786, -0.14489016, -0.54187966],
#        [-0.09537277, -0.25936212, -0.84366505, -0.83261074],
#        [ 0.63876588, -0.14357546, -0.59448951, -0.58495093],
#        [ 0.03514077, -0.0277888 , -0.57282207, -0.5634153 ],
#        [-0.34824275,  0.08799786, -0.33989711, -0.33190722],
#        [ 1.6420887 ,  0.20378452, -0.32364653,  0.15533654],
#        [-0.93555366,  0.31957119, -0.04196983, -0.03579223],
#        [ 1.19344841,  0.43535785,  0.03386621,  0.17418022],
#        [-1.37603685,  0.55114451, -0.16114074, -0.15423822],
#        [ 1.51157516, -0.14357546, -1.00617084, -0.99412801],
#        [-0.19325792, -0.0277888 , -0.6486581 , -0.63879002],
#        [-1.46576491, -1.88037538, -1.2120115 , -1.19871655],
#        [ 1.78075933,  0.20378452, -0.07988785,  0.26301472],
#        [ 1.4300042 ,  0.08799786, -0.32906339, -0.3211394 ],
#        [ 1.65024579, -0.72250877,  2.18435946,  1.97509775],
#        [-1.66969231, -0.60672211,  0.71639051,  1.05444933],
#        [-0.31561436, -0.49093544,  1.29599449,  1.42863099],
#        [-1.72679198, -0.37514878,  1.52350259,  1.11636428],
#        [-0.75609755, -1.99616204, -0.71366042, -1.1071901 ],
#        [-0.33192855, -1.88037538, -0.35073082, -0.54457162],
#        [-0.73162626, -1.76458872, -0.58365579, -0.97797628],
#        [-0.30745726, -1.64880206, -0.35073082, -0.54457162],
#        [-0.14431534, -1.5330154 , -0.33448025, -0.52841989],
#        [ 0.06776915,  0.31957119,  0.13678654, -0.06001982],
#        [-0.42981371, -1.41722874, -0.22072619, -0.4153578 ],
#        [ 0.48378105, -1.30144208,  0.01219877,  0.35454117],
#        [-0.91923947, -1.18565541,  0.0880348 ,  0.42991589],
#        [-0.91923947, -1.06986875,  0.62972076,  0.96830678],
#        [ 0.76927942, -0.95408209,  0.31012605, -0.08963132],
#        [-1.6941636 , -0.83829543,  1.08473697,  0.88216424],
#        [ 1.12819164, -0.72250877,  1.17682358,  0.97369069],
#        [ 1.40553291, -0.60672211,  0.71097366,  0.30877794],
#        [ 0.23906817, -0.49093544,  1.19849102,  0.99522633],
#        [-1.59627844, -0.37514878,  1.44766656,  1.24288614],
#        [ 1.12819164,  0.43535785,  0.13678654, -0.2619164 ],
#        [ 1.44631839, -0.25936212,  2.61229137,  2.40042655],
#        [ 1.74813094, -0.14357546,  1.86476475,  1.45555054],
#        [-1.23736622, -0.0277888 ,  1.88101533,  2.21198974],
#        [-0.0219589 , -1.99616204, -0.75157843, -0.94298088],
#        [-1.31893718, -1.88037538, -0.63240752, -1.02643146],
#        [-0.09537277, -1.76458872, -0.6215738 , -0.81376706],
#        [ 0.23091108, -1.64880206, -0.43740058, -0.29421985],
#        [-0.35639984, -1.5330154 , -0.35073082, -0.7464682 ],
#        [ 0.62245169, -1.41722874, -0.29656223, -0.69262911],
#        [ 0.65508007, -1.30144208, -0.15572388,  0.18763999],
#        [ 1.05477778,  0.55114451,  0.41304638,  0.01266295],
#        [ 0.58166621, -1.18565541,  0.03928307, -0.35882676],
#        [-0.81319722, -1.06986875,  0.58096903,  0.71795502],
#        [-0.80504013, -0.95408209,  0.29387547,  0.43260785],
#        [ 0.32063913, -0.83829543,  0.52138357,  0.65873202],
#        [-1.53917877, -0.72250877,  1.1334887 ,  1.26711373],
#        [-1.31078008, -0.60672211,  2.40645071,  1.99394143],
#        [-0.27482888, -0.49093544,  2.19519318,  2.32235987],
#        [-0.72346916, -0.37514878,  2.2331112 ,  2.36004723],
#        [-1.04159591, -0.25936212,  1.63725665,  1.76781726],
#        [-0.49507047, -0.14357546,  1.66434094,  1.25634591],
#        [ 0.61429459,  0.66693117,  0.51054985,  0.3114699 ],
#        [-1.13948106, -0.0277888 ,  2.75312972,  2.3385116 ],
#        [ 1.2260768 ,  0.08799786,  2.57979021,  2.7046174 ],
#        [ 0.92426424,  0.20378452,  2.90480179,  2.48926105],
#        [ 1.2179197 ,  0.31957119,  2.55812278,  2.14469088],
#        [-1.4820791 ,  0.43535785,  2.95355353,  3.07610712],
#        [-0.37271403,  0.55114451,  3.051057  ,  3.17301748],
#        [-0.14431534,  0.66693117,  2.2601955 ,  2.38696678],
#        [ 1.61761741, -2.22773537, -0.44281744, -0.43420149],
#        [-0.11168696, -1.06986875,  0.12053596,  0.26032276],
#        [-1.71863488, -1.64880206, -0.44281744, -0.43420149],
#        [-1.63706392,  0.78271783,  0.22345629,  0.02612273],
#        [ 0.63060878, -0.49093544,  0.91681432,  1.05175737],
#        [-1.22105202,  0.89850449,  0.06636736, -0.13001063],
#        [ 0.1738114 ,  1.01429115,  1.17140672,  0.96830678],
#        [-0.84582561,  1.13007782,  0.17470456,  0.17956413],
#        [-1.75126327,  1.24586448, -0.30197909, -0.29421985],
#        [-1.20473783, -1.76458872, -1.04950571, -1.03719928],
#        [ 0.77743651,  1.36165114,  0.86264572,  0.66142398],
#        [ 0.27985365,  1.4774378 ,  1.27974391,  1.07598496],
#        [ 0.57350911,  1.59322446,  1.00890093,  1.34518041],
#        [-0.2258863 ,  1.70901112,  0.62972076,  0.22801931],
#        [ 0.81822199,  1.82479778,  1.66434094,  1.99663338],
#        [-0.17694373, -1.06986875, -0.96283596, -1.15295332],
#        [-1.63706392, -0.95408209, -0.91408422, -1.30639473],
#        [ 0.87532166, -0.83829543, -0.86533249, -1.25793955],
#        [-0.16878663, -0.72250877, -0.94658538, -0.59841071],
#        [ 1.40553291, -0.60672211, -0.68115926, -0.87299006],
#        [ 0.65508007, -1.64880206, -1.03325513, -1.02104756],
#        [ 0.67955136, -0.49093544, -0.73532786, -1.12872573],
#        [-1.37603685, -0.37514878, -0.75157843, -0.40458999],
#        [ 1.78891642, -0.25936212, -0.39948256, -0.5930268 ],
#        [ 0.45115267, -0.14357546, -0.48615231, -0.34267503],
#        [-0.11984406, -0.0277888 , -0.38323198, -0.57687507],
#        [ 1.02214939,  0.08799786, -0.30197909, -0.15962213],
#        [ 1.34843324,  0.20378452, -0.0853047 ,  0.25763081],
#        [ 1.60946031,  0.31957119, -0.09072156,  0.2522469 ],
#        [ 1.17713422,  0.43535785,  0.09345166,  0.23340322],
#        [-0.56848434,  0.55114451, -0.67032554, -1.06411883],
#        [-0.2340434 , -1.5330154 , -0.97908654, -0.96720847],
#        [ 0.02698367,  0.66693117, -0.18280818, -0.37767044],
#        [ 1.13634874,  0.78271783,  0.63513762,  0.77179411],
#        [-1.39235104,  0.89850449,  0.64055448,  0.77717802],
#        [ 1.43816129,  1.01429115,  0.68930622,  0.8256332 ],
#        [-0.91923947,  1.13007782,  0.45638125,  0.59412512],
#        [-0.69899788,  1.24586448,  0.27220803,  0.6129688 ],
#        [-1.0660672 ,  1.36165114,  0.91139746,  1.04637346],
#        [-1.30262299,  1.4774378 ,  0.47263183,  0.61027684],
#        [ 1.50341806,  1.59322446,  0.88973002,  1.02483783],
#        [ 0.3777388 ,  1.70901112,  0.94389862,  1.07867692],
#        [-1.08238139, -1.41722874, -1.19034406, -0.63879002],
#        [ 1.34027614,  1.82479778,  1.6697578 ,  1.80012071],
#        [ 0.07592625,  0.08799786, -0.87074935, -0.72493257],
#        [ 1.81338771,  0.20378452, -0.09072156,  0.05035032],
#        [-0.35639984,  0.31957119, -0.94116852, -0.79492338],
#        [-0.36455694,  0.43535785,  0.00678191,  0.01266295],
#        [-0.8621398 ,  0.55114451, -0.41573314, -0.40728194],
#        [-0.96002495,  0.66693117, -0.38864884, -0.3803624 ],
#        [ 0.46746686,  0.78271783,  0.42929696,  0.56720557],
#        [ 0.54088073,  0.89850449,  1.35016309,  0.94407919],
#        [ 0.48378105,  1.01429115,  0.66763878,  0.80409756],
#        [ 1.61761741, -1.30144208, -0.93575166, -1.32793036],
#        [-1.09869558,  1.13007782,  0.25595745,  0.39492049],
#        [ 0.33695332,  1.24586448,  0.78139283,  0.91715965],
#        [ 1.11187745,  1.36165114,  1.35557995,  0.9494631 ],
#        [-0.36455694,  1.4774378 ,  1.59392177,  1.18635509],
#        [-1.14763816,  1.59322446,  1.03056837,  1.16481946],
#        [ 0.72849394,  1.70901112,  1.28516077,  0.87947229],
#        [ 0.32879623,  1.82479778,  1.4964183 ,  1.62783562],
#        [ 0.95689263,  1.24586448,  1.36099681,  0.95484701],
#        [ 0.99767811,  1.36165114,  0.79764341,  1.13520796],
#        [-0.05458729,  1.4774378 ,  0.94931548,  1.28595741],
#        [ 0.85085038, -1.18565541, -0.96825282, -0.61994634],
#        [ 1.76444514,  1.59322446,  1.32307879,  0.91715965],
#        [-1.10685268,  1.70901112,  0.70013994,  1.0382976 ],
#        [ 0.36142461,  1.82479778,  1.59933863,  1.59553217],
#        [ 1.15266293, -0.14357546, -0.49156917, -0.88644983],
#        [-0.19325792, -0.0277888 , -0.58907265, -0.108475  ],
#        [-0.37271403,  0.08799786, -0.87616621, -0.8649142 ],
#        [-1.49023619,  0.20378452, -0.38323198, -0.77877165],
#        [-0.42165661,  0.31957119, -0.95200224, -0.94028892],
#        [-1.54733587,  0.43535785, -0.38864884, -0.3803624 ],
#        [ 1.20160551,  0.55114451, -0.06363727, -0.05732786],
#        [-0.10352986, -1.06986875, -0.76241215, -0.95374869],
#        [ 0.23091108,  0.66693117,  0.46179811,  0.4649113 ],
#        [ 0.09224044,  0.78271783,  0.30470919,  0.77986997],
#        [ 0.10039754,  0.89850449,  0.13678654,  0.14187677],
#        [ 0.88347876,  1.01429115,  0.6513882 ,  0.65334811],
#        [ 0.36958171,  1.13007782,  1.18224044,  1.18097119],
#        [-0.96002495,  1.24586448,  0.3426272 , -0.05732786],
#        [-1.56365006,  1.36165114,  0.40762952,  0.00727904],
#        [ 0.23091108,  1.4774378 ,  0.88973002,  0.8902401 ],
#        [-0.2340434 ,  1.59322446,  1.30141135,  1.29941718],
#        [-1.38419395,  1.70901112,  0.60263646,  0.60489293]])

# %%
df_stan = pd.DataFrame(sc_stan.fit_transform(df_n), columns=df_n.columns)
df_stan[:5]
# Out:
#      height       age    salary  expenditure
# 0 -0.625584 -1.996162 -1.222845    -1.613278
# 1 -0.013802 -0.954082 -0.887000    -1.077579
# 2 -0.103530  1.824798  0.499716     0.502599
# 3 -1.163952 -1.301442 -1.244513    -1.096422
# 4  1.552361 -1.185655 -1.065756    -0.514960

# %%
#시각화 
fig, ax = plt.subplots( nrows= 1 , ncols=3, figsize=(14, 5))

sns.histplot(x='salary', data=df_n, ax= ax[0])
sns.histplot(x='salary', data=df_minmax, ax= ax[1], color='green')
sns.histplot(x='salary', data=df_stan, ax= ax[2], color='orange')

ax[0].set_title('df salary histplot')
ax[1].set_title('df_minmax salary histplot')
ax[2].set_title('df_stan salary histplot')
plt.show()

# %%
# StandardScaler class
from sklearn.preprocessing import StandardScaler

# %%
# StandardScaler 모델링

# %%
# StandardScaler fit, transform

# %% [markdown]
# ### 정규화, train, test분리시 적용
#
# - train으로 정규화 모델을 만들었을때
# - test도 train 정규화 모델을 사용해야 같은 scale로 scaling된다

# %%
# train_test_split
from sklearn.model_selection import train_test_split

# %%
# 연속형 변수 추출
df_n1= df_train1[['height','age','salary','expenditure']]
df_n1[:5]
# Out:
#      height  age  salary  expenditure
# 193   184.0   43    6530         5405
# 243   180.4   48    7560         6185
# 152   166.2   35   10410         9285
# 184   177.6   25    4450         3075
# 190   182.1   40    5800         4675

# %%
# train data StandardScaler fit까지로 StandardScaler를 만든다
from sklearn.preprocessing import StandardScaler
sc_stan1 = StandardScaler().fit(df_n1)
sc_stan1
# Out:
# StandardScaler()

# %%
# train에 대해 transform을 실행하여 train data를 StandardScaling
sc_tran_tr = sc_stan1.transform(df_n1)
sc_tran_tr[:5]
# Out:
# array([[ 1.18368864,  0.4262369 ,  0.09722408,  0.2420165 ],
#        [ 0.89198004,  0.99132369,  0.63216424,  0.64545122],
#        [-0.25864828, -0.47790198,  2.11233847,  2.24884563],
#        [ 0.66509559, -1.60807557, -0.98304343, -0.96311543],
#        [ 1.02973132,  0.08718482, -0.28190827, -0.13555702]])

# %%
# test data는 traind의 StandardScaler를 적용해 transform
df_n2 = df_test1[['height','age','salary','expenditure']]
sc_tran_te = sc_stan1.transform(df_n2)

# %%
# train data df화
df_train_std = pd.DataFrame(sc_tran_tr,columns=df_n1.columns)

# %%
# test data df화
df_test_std = pd.DataFrame(sc_tran_te,columns=df_n2.columns)

# %%
# train data EDA
df_train_std.describe()
# Out:
#              height           age        salary   expenditure
# count  1.750000e+02  1.750000e+02  1.750000e+02  1.750000e+02
# mean   3.438519e-16  6.772360e-17 -7.930164e-17  1.839798e-16
# std    1.002869e+00  1.002869e+00  1.002869e+00  1.002869e+00
# min   -1.725294e+00 -2.173162e+00 -1.694566e+00 -1.865671e+00
# 25%   -8.663745e-01 -7.039367e-01 -7.077830e-01 -7.820870e-01
# 50%   -8.038192e-02  8.718482e-02 -1.520684e-01 -1.303848e-01
# 75%    8.879285e-01  7.652890e-01  5.724379e-01  6.881222e-01
# max    1.815724e+00  1.782445e+00  2.932926e+00  3.066060e+00

# %%
#시각화 
fig, ax = plt.subplots( nrows= 1 , ncols=2, figsize=(14, 5))

ax[0].set_title('train ')
ax[1].set_title('test')

df_train_std.plot.hist(ax= ax[0])
df_test_std.plot.hist(ax= ax[1] )
plt.show()

# %% [markdown]
# ## 4-1 Feature Engeering
#
# 변수 선택
#
# - 종속변수(expenditure)
#
# - 독립변수 수치형 변수중 회귀계수가 높은 2개 선정 (feature selection) 하시오
# - 독립변수 수치형 변수중 t검정 통계량의 p-value가 0.05이하인것을 선정하시오

# %%
# ols 방식
#종속변수: 소비액 / 독립변수: 신장 / 나이 / 연봉 
from statsmodels.formula.api import ols

model_feature1 = ols(formula='expenditure~height+age+salary', data = df).fit()
model_feature1.summary()
# 각 요소가 선형성에 유의미한 영향을 주는가
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            expenditure   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     1484.
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):          3.46e-157
# Time:                        13:11:50   Log-Likelihood:                -1867.8
# No. Observations:                 250   AIC:                             3744.
# Df Residuals:                     246   BIC:                             3758.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1540.7355    391.682     -3.934      0.000   -2312.213    -769.258
# height        -0.0220      2.214     -0.010      0.992      -4.382       4.338
# age           12.5898      3.688      3.414      0.001       5.326      19.853
# salary         0.9472      0.017     54.885      0.000       0.913       0.981
# ==============================================================================
# Omnibus:                        2.905   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.234   Jarque-Bera (JB):                2.122
# Skew:                          -0.013   Prob(JB):                        0.346
# Kurtosis:                       2.549   Cond. No.                     9.57e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.57e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# LinearRegression 방식
from sklearn.linear_model import LinearRegression

model_feature2 = LinearRegression().fit(X = df[['height','age','salary']], y = df[['expenditure']])
model_feature2.coef_,model_feature2.feature_names_in_
# Out:
# (array([[-0.021977  , 12.58979578,  0.94721785]]),
#  array(['height', 'age', 'salary'], dtype=object))

# %% [markdown]
# ## 4-2 Feature Engeering
#
# 보스톤 집값 데이터 셋(출처: sklearn 라이브러리)

# %% [markdown]
# 데이터(sklearn_boston.csv) 사이즈 : 506 X 14
# <br>
# <br> <b>crim:</b> 자치시 별 1인당 범죄율
# <br> <b>zn:</b> 25,000 평방피트 초과하는 거주지역 비율
# <br> <b>indus:</b> 비소매상업지역 점유하고 있는 토지 비율
# <br> <b>chas:</b> 찰스강에 대한 더미 변수(강 경계 1, 아니면 0)
# <br> <b>nox:</b> 10ppm 당 농축 일산화 질소
# <br> <b>rm:</b> 주택 1가구당 평균 방의 개수
# <br> <b>age:</b> 1940년 이전 건축된 소유주택 비율
# <br> <b>dis:</b> 5개 보스턴 직업센터까지의 접근성 지수
# <br> <b>rad:</b> 방사형 도로까지의 접근성 지수
# <br> <b>tax:</b> 10,000 달러 당 재산세 율
# <br> <b>ptratio:</b> 자치시 별 학생 / 교사 비율
# <br> <b>b:</b> 자치시별 흑인의 비율
# <br> <b>lstat:</b> 모집단 하위계층 비율
# <br> <b>price:</b> 본인 소유 주택 가격
#
# <br> 1. 종속변수 : price
# <br> 2. 독립변수 : price를 제외한 모든 변수
# <br> 3. feature selection을 통해 p-value 값 0.05 미만 / coef 절대값 0.5이상인 변수를 선택하시오
# <br> ------------------------------------------------------------------------------------------
# <br> 4. train, test 분리하여 다음을 수행 (train_size=0.8, random_state=123)
# <br> 5. 선택된 독립변수를 사용하여 선형회귀식을 만들고 RMSE를 구하시오

# %%
# 파일 로드 
boston = pd.read_csv('.\\data\\sklearn_boston.csv')
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      ptratio       b  lstat  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    float64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    float64
#  9   tax      506 non-null    float64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
# step1) 변수 생성
boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'price'],
#       dtype='object')

# %%
# join
' + '.join(boston.columns)
'A' + ' + '.join(boston.columns.drop('price'))
'price ~ ' + ' + '.join(boston.columns.drop('price'))
# Out:
# 'price ~ crim + zn + indus + chas + nox + rm + age + dis + rad + tax + ptratio + b + lstat'

# %%
'price ~ ' + ' + '.join(boston.columns.drop('price'))
# Out:
# 'price ~ crim + zn + indus + chas + nox + rm + age + dis + rad + tax + ptratio + b + lstat'

# %%
# step2) formula 생성

# %%
# step3) feature selection을 통해 p-value 값 0.05 미만 / coef 절대값 0.5이상인 변수를 선택하시오
# ols, fit, summary
from statsmodels.formula.api import ols
model_self4 = ols(formula= 'price ~ crim + zn + indus + chas + nox + rm + age + dis + rad + tax + ptratio + b + lstat',data = boston).fit()

# %%
model_self4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):          6.72e-135
# Time:                        13:29:26   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.4595      5.103      7.144      0.000      26.432      46.487
# crim          -0.1080      0.033     -3.287      0.001      -0.173      -0.043
# zn             0.0464      0.014      3.382      0.001       0.019       0.073
# indus          0.0206      0.061      0.334      0.738      -0.100       0.141
# chas           2.6867      0.862      3.118      0.002       0.994       4.380
# nox          -17.7666      3.820     -4.651      0.000     -25.272     -10.262
# rm             3.8099      0.418      9.116      0.000       2.989       4.631
# age            0.0007      0.013      0.052      0.958      -0.025       0.027
# dis           -1.4756      0.199     -7.398      0.000      -1.867      -1.084
# rad            0.3060      0.066      4.613      0.000       0.176       0.436
# tax           -0.0123      0.004     -3.280      0.001      -0.020      -0.005
# ptratio       -0.9527      0.131     -7.283      0.000      -1.210      -0.696
# b              0.0093      0.003      3.467      0.001       0.004       0.015
# lstat         -0.5248      0.051    -10.347      0.000      -0.624      -0.425
# ==============================================================================
# Omnibus:                      178.041   Durbin-Watson:                   1.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              783.126
# Skew:                           1.521   Prob(JB):                    8.84e-171
# Kurtosis:                       8.281   Cond. No.                     1.51e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# p-value 값 0.05 미만 / coef 절대값 0.5이상인 변수를 선택
model_self4.params
# chas,nox, rm, dis,ptratio,lstat

model_self4.pvalues<0.5
model_self4.params.index[(model_self4.pvalues<0.5) & (model_self4.params.abs()>0.5)]
# Out:
# Index(['Intercept', 'chas', 'nox', 'rm', 'dis', 'ptratio', 'lstat'], dtype='object')

# %%
idx = model_self4.params.index[(model_self4.pvalues<0.5)& (model_self4.params.abs()>0.5)]

# %%
idx.drop('Intercept')
# Out:
# Index(['chas', 'nox', 'rm', 'dis', 'ptratio', 'lstat'], dtype='object')

# %%
# step4) train, test 분리(train_size=0.8, random_state=123)
from sklearn.model_selection import train_test_split
df_train2, df_test2 = train_test_split(boston[['chas','nox', 'rm', 'dis','ptratio','lstat','price']],train_size=0.8,random_state=123)

# %%
# formula 생성
formu = 'price~'+ ' + '.join(df_train2.columns.drop('price'))
print(formu)
# Out:
# price~chas + nox + rm + dis + ptratio + lstat

# %%
# step5) 선택된 독립변수를 사용하여 선형회귀식 생성
from statsmodels.formula.api import ols
model_self5 = ols(formula=formu,data=df_train2).fit()

# %%
# summary
model_self5.summary()
pred = model_self5.predict(df_test2.drop('price',axis = 1))

# %%
# step5) RMSE
from sklearn.metrics import mean_squared_error

mean_squared_error(pred, df_test2['price'])**0.5
# Out:
# 5.6044574962178615

# %% [markdown]
# ## 4-3 Feature Engeering - 다중 공선성 VIF

# %%
boston

# %%
# 상관관계 분석
boston.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# b       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# price   -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               dis       rad       tax   ptratio         b     lstat     price
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# b        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# price    0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
# 상관관계 매트릭스 시각화 
plt.figure( figsize=(10, 10))
sns.heatmap(boston.corr(), annot=True , cbar=True)
plt.show()

# %%
#다중 공선성 VIF 구하기 

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(boston.values, i) for i in range(boston.shape[1])]
vif["features"] = boston.columns
vif.sort_values('VIF Factor', ascending = False)
# Out:
#     VIF Factor features
# 5   136.101743       rm
# 10   87.227233  ptratio
# 4    74.004269      nox
# 9    61.939713      tax
# 13   24.503206    price
# 6    21.398863      age
# 11   21.351015        b
# 7    15.430455      dis
# 8    15.369980      rad
# 2    14.485874    indus
# 12   12.615188    lstat
# 1     2.910004       zn
# 0     2.131404     crim
# 3     1.176266     chas

# %% [markdown]
# ##  $\Sigma$ (시그마) Quiz

# %% [markdown]
# ### quiz 1) 자전거공유플랫폼 데이터 셋 활용
#
# □ df_bike.csv 파일을 읽고 (데이터 객체명 : df_bike)
# train, test로 분리하시오 (random_state=123)
#
#   - sklearn.model_selection / train_test_split 메소드를 쓸 것(데이터셋은 df_bike_train, df_bike_test로 명명)
#
#   1_1. df_bike_train내 대여건수인 'riders' 변수와 'temp', 'feelslike', 'humidity', 'windspeed', 'casual'
#     <br> 간 pearson 상관계수를 확인, 'riders' 변수와 비교해 가장 상관계수 절대값이 큰 변수를 구하시오
#
# - df_bike_train으로 자건거 대여건수(riders)와 'temp'변수와 단일 회귀분석을 실시하고
#
#   1_2. 회귀계수를 구하시오
#
#   1_3. df_bike_test의 대여건수를 예측(pred_count)하고, 예측치의 중앙값을 구하시오
#
#   1_4. df_bike_test의 대여건수 예측치(pred_count)와 실제값(riders)의 RMSE를 구하시오
#
#   1_5. df_bike_train의 자건거 대여건수(riders)를 종속변수로 하고, 'temp', 'feelslike', 'humidity', 'windspeed', 'casual'
#
#     5개 독립변수로 다중 회귀분석을 하고자 한다.
#
#
#     이때 해당 모델의 결정계수를 구하고 통계적으로 유의미한 변수와 해당변수의 회귀값을 구하시오
#
# ** bike dataset 설명
# https://www.scikit-yb.org/en/latest/api/datasets/bikeshare.html

# %%
# 파일 로딩 
df_bike = pd.read_csv('.\\data\\yellowbrick_bikeshare.csv')

# # 데이터 분리 
from sklearn.model_selection import train_test_split
df_bike_train, df_bike_test = train_test_split(df_bike, train_size= 0.7, random_state=123)
print('df', len(df_bike), 'df_bike_train', len(df_bike_train), 'df_bike_test', len(df_bike_test))

df_bike_train[['riders', 'temp', 'feelslike', 'humidity', 'windspeed', 'casual']].corr().abs().sort_values('riders', ascending=False)
# casual, 0.695529

# %%
# 관련 메소드 호출
from sklearn.linear_model import LinearRegression
from statsmodels.formula.api import ols
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# 1_2. 모델 Training, 회귀계수 (statemodels)

# # OLS 모델, 1_2. 모델 Training, 회귀계수 (statemodels)

# 1_2. 모델 Training, 회귀계수 (sklearn)    
from sklearn.linear_model import LinearRegression

# 1_3. df_bike_test 예측치의 중앙값을 구하시오

# 1_4. df_bike_test pred_count와 count의 RMSE

# 1_5. feature selection

# %% [markdown]
# ## quiz 2) 다이아몬드 데이터 셋 활용
#
# - diamond.csv 파일을 읽고 (df_dia)
# train, test로 분리하시오 (random_state=123) (df_dia_train, df_dia_test)
#
# - df_dia_train으로 선형회귀분석을 실시하고 아래에 답하시오
#
#   2_1. 종속변수(price), 독립변수(carat, depth)일때 독립변수의 회귀계수를 구하시오
#
#   2_2. 종속변수(price), 독립변수(carat, depth, color)일때 df_dia_test price의 예측값 평균을 구하시오
#
#     'color'는 더미변수로 변형하고 가변수를 생성시 마지막 변수 하나를 제거하시오
#
#   2_3. 2_2 조건으로 df_dia_test의 값이 (carat: 1, color: 'E' , depth: 50)일때 price 예측값을 구하시오
#
# ** dia dataset 설명 https://www.kaggle.com/datasets/shivam2503/diamonds

# %%
# 파일 로딩 
df_dia = pd.read_csv('.\\data\\diamonds.csv')

# 데이터 분리 
from sklearn.model_selection import train_test_split
df_dia_train, df_dia_test = train_test_split(df_dia, train_size= 0.7, random_state=123)
print('df', len(df_dia), 'df_dia_train', len(df_dia_train), 'df_dia_test', len(df_dia_test))
df_dia.head(5)

# %%
# 관련 메소드 호출
from sklearn.linear_model import LinearRegression
from statsmodels.formula.api import ols
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# 2_1. 모델 Training, 회귀계수 (statemodels)

# 2_1. 모델 Training, 회귀계수 (sklearn)    
# X, y값 세팅

# 2_2. 범주형 data 가변수화  

# 데이터 분리 
from sklearn.model_selection import train_test_split

# X, y값 세팅  ['carat', 'depth', 'color_D', 'color_E', 'color_F', 'color_G', 'color_H', 'color_I'] ['price']

# LinearRegression, fit, predict
from sklearn.linear_model import LinearRegression

# 2_2. answer (mean)

# 2_3. 독립변수 직접입력 방식
# df_dia_test(carat: 1, depth: 50, color: 'E'  )일때 price 예측값

# 2_3. answer

# %% [markdown]
# ## $\Omega$(오메가) Quiz
#
# - yellowbrick_bikeshare.csv 파일을 읽고 (객체명 : df_bike)
#
#   3-1 season column을 사용하여 여름(df_bike_summer)과 겨울(df_bike_winter)로 구분하시오
#
#   3_2 df_bike_summer, df_bike_winter를  train, test로 분리하시오 (df_summer_tr, df_summer_te, df_winter_tr, df_winter_te, random_state=123 )
#
#   3_3. statemodels를 사용하여 종속변수(riders), 독립변수(temp)로 train 시키고 여름과 겨울의 RMSE차이를 구하시오

# %%
# 파일 로딩 
df_bike = pd.read_csv('.\\data\\yellowbrick_bikeshare.csv')

# 3-1 데이터 분리

# 3-2 train, test 분리

from sklearn.model_selection import train_test_split

# 3-3 train, predict
from statsmodels.formula.api import ols


# 3-3 RMSE

# %%
#시각화 
fig, ax = plt.subplots( nrows= 1 , ncols=2, figsize=(14, 5))

sns.regplot(x='temp', y='riders', data=df_summer_tr, ax= ax[0], color='green')
sns.regplot(x='temp', y='riders', data=df_winter_tr, ax= ax[1])

ax[0].set_title('df_summer_tr')
ax[1].set_title('df_winter_tr')
plt.show()
